# %%
import os
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from tqdm import tqdm
import pickle
import logging
logger = logging.getLogger(__name__)
logging.basicConfig(format='%(asctime)s - %(levelname)s - %(name)s -   %(message)s',
                    datefmt='%m/%d/%Y %H:%M:%S',
                    level=logging.INFO)

# %%
with open("all_data.txt",'r') as f:
    sentences=[]
    for idx,l in enumerate(f.readlines()):
        sentences.append(l.split())

# %%
print(len(sentences))
# Out:
# 500000

# %%
sentences[0]
# Out:
# ['1', '2', '3', '4', '5', '6', '7']

# %%
w2v=Word2Vec(sentences,size=300, window=15,min_count=1,sg=1,workers=32,iter=100)
# Out:
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   collecting all words and their counts
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #10000, processed 34936 words, keeping 3256 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #20000, processed 69844 words, keeping 4644 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #30000, processed 104845 words, keeping 5708 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #40000, processed 139823 words, keeping 6579 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #50000, processed 174721 words, keeping 7350 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #60000, processed 209897 words, keeping 8021 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #70000, processed 244659 words, keeping 8597 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #80000, processed 279556 words, keeping 9206 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #90000, processed 314030 words, keeping 9727 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #100000, processed 349107 words, keeping 10209 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #110000, processed 383849 words, keeping 10657 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #120000, processed 418338 words, keeping 11139 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #130000, processed 453210 words, keeping 11568 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #140000, processed 488231 words, keeping 12004 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #150000, processed 523208 words, keeping 12369 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #160000, processed 557889 words, keeping 12749 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #170000, processed 592830 words, keeping 13085 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #180000, processed 627750 words, keeping 13394 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #190000, processed 662724 words, keeping 13737 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #200000, processed 697783 words, keeping 14062 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #210000, processed 732681 words, keeping 14363 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #220000, processed 767621 words, keeping 14646 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #230000, processed 802446 words, keeping 14940 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #240000, processed 837555 words, keeping 15216 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #250000, processed 872164 words, keeping 15459 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #260000, processed 907101 words, keeping 15708 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #270000, processed 941739 words, keeping 15973 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #280000, processed 976651 words, keeping 16266 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #290000, processed 1011149 words, keeping 16505 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #300000, processed 1046097 words, keeping 16728 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #310000, processed 1081021 words, keeping 16987 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #320000, processed 1115776 words, keeping 17223 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #330000, processed 1150907 words, keeping 17455 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #340000, processed 1185790 words, keeping 17688 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #350000, processed 1221007 words, keeping 17899 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #360000, processed 1256116 words, keeping 18166 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #370000, processed 1291139 words, keeping 18386 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #380000, processed 1325746 words, keeping 18592 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #390000, processed 1360591 words, keeping 18787 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #400000, processed 1395341 words, keeping 19016 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #410000, processed 1428702 words, keeping 19191 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #420000, processed 1462527 words, keeping 19342 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #430000, processed 1496363 words, keeping 19517 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #440000, processed 1530062 words, keeping 19695 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #450000, processed 1563804 words, keeping 19858 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #460000, processed 1597457 words, keeping 20022 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #470000, processed 1631164 words, keeping 20185 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #480000, processed 1664858 words, keeping 20321 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   PROGRESS: at sentence #490000, processed 1698484 words, keeping 20447 word types
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   collected 20601 word types from a corpus of 1732317 raw words and 500000 sentences
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   Loading a fresh vocabulary
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   effective_min_count=1 retains 20601 unique words (100% of original 20601, drops 0)
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   effective_min_count=1 leaves 1732317 word corpus (100% of original 1732317, drops 0)
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   deleting the raw counts dictionary of 20601 items
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   sample=0.001 downsamples 57 most-common words
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   downsampling leaves estimated 1220251 word corpus (70.4% of prior 1732317)
# 03/07/2021 09:48:31 - INFO - gensim.models.base_any2vec -   estimated required memory for 20601 words and 300 dimensions: 59742900 bytes
# 03/07/2021 09:48:31 - INFO - gensim.models.word2vec -   resetting layer weights
# 03/07/2021 09:48:34 - INFO - gensim.models.base_any2vec -   training model with 32 workers on 20601 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=15
# 03/07/2021 09:48:35 - INFO - gensim.models.base_any2vec -   EPOCH 1 - PROGRESS: at 33.84% examples, 415263 words/s, in_qsize 64, out_qsize 0
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:48:36 - INFO - gensim.models.base_any2vec -   EPOCH - 1 : training on 1732317 raw words (1220399 effective words) took 1.8s, 687256 effective words/s
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   EPOCH 2 - PROGRESS: at 40.69% examples, 502063 words/s, in_qsize 59, out_qsize 3
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:48:37 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:48:38 - INFO - gensim.models.base_any2vec -   EPOCH - 2 : training on 1732317 raw words (1220534 effective words) took 1.6s, 751754 effective words/s
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   EPOCH 3 - PROGRESS: at 44.14% examples, 539992 words/s, in_qsize 64, out_qsize 5
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:48:39 - INFO - gensim.models.base_any2vec -   EPOCH - 3 : training on 1732317 raw words (1220881 effective words) took 1.6s, 751425 effective words/s
# 03/07/2021 09:48:40 - INFO - gensim.models.base_any2vec -   EPOCH 4 - PROGRESS: at 51.56% examples, 594341 words/s, in_qsize 63, out_qsize 0
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:48:41 - INFO - gensim.models.base_any2vec -   EPOCH - 4 : training on 1732317 raw words (1220423 effective words) took 1.5s, 792364 effective words/s
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   EPOCH 5 - PROGRESS: at 49.29% examples, 607012 words/s, in_qsize 64, out_qsize 0
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:48:42 - INFO - gensim.models.base_any2vec -   EPOCH - 5 : training on 1732317 raw words (1220057 effective words) took 1.5s, 790918 effective words/s
# 03/07/2021 09:48:43 - INFO - gensim.models.base_any2vec -   EPOCH 6 - PROGRESS: at 44.13% examples, 540329 words/s, in_qsize 63, out_qsize 0
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:48:44 - INFO - gensim.models.base_any2vec -   EPOCH - 6 : training on 1732317 raw words (1220372 effective words) took 1.6s, 780993 effective words/s
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   EPOCH 7 - PROGRESS: at 48.14% examples, 557405 words/s, in_qsize 62, out_qsize 1
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:48:45 - INFO - gensim.models.base_any2vec -   EPOCH - 7 : training on 1732317 raw words (1220664 effective words) took 1.6s, 786808 effective words/s
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   EPOCH 8 - PROGRESS: at 48.71% examples, 573701 words/s, in_qsize 63, out_qsize 0
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:48:47 - INFO - gensim.models.base_any2vec -   EPOCH - 8 : training on 1732317 raw words (1220030 effective words) took 1.5s, 789482 effective words/s
# 03/07/2021 09:48:48 - INFO - gensim.models.base_any2vec -   EPOCH 9 - PROGRESS: at 48.13% examples, 583318 words/s, in_qsize 60, out_qsize 3
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:48:49 - INFO - gensim.models.base_any2vec -   EPOCH - 9 : training on 1732317 raw words (1220408 effective words) took 1.6s, 771988 effective words/s
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   EPOCH 10 - PROGRESS: at 51.01% examples, 626815 words/s, in_qsize 64, out_qsize 0
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:48:50 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# ...
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:51:09 - INFO - gensim.models.base_any2vec -   EPOCH - 97 : training on 1732317 raw words (1220487 effective words) took 1.6s, 774038 effective words/s
# 03/07/2021 09:51:10 - INFO - gensim.models.base_any2vec -   EPOCH 98 - PROGRESS: at 49.86% examples, 594893 words/s, in_qsize 63, out_qsize 0
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:51:11 - INFO - gensim.models.base_any2vec -   EPOCH - 98 : training on 1732317 raw words (1219712 effective words) took 1.6s, 780249 effective words/s
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   EPOCH 99 - PROGRESS: at 42.41% examples, 523460 words/s, in_qsize 63, out_qsize 1
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:51:12 - INFO - gensim.models.base_any2vec -   EPOCH - 99 : training on 1732317 raw words (1220630 effective words) took 1.6s, 783961 effective words/s
# 03/07/2021 09:51:13 - INFO - gensim.models.base_any2vec -   EPOCH 100 - PROGRESS: at 48.70% examples, 593062 words/s, in_qsize 64, out_qsize 0
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 31 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 30 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 29 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 28 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 27 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 26 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 25 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 24 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 23 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 22 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 21 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 20 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 19 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 18 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 17 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 16 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 15 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 14 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 13 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 12 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 11 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 10 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 9 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 8 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 7 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 6 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 5 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 4 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 3 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 2 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 1 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   worker thread finished; awaiting finish of 0 more threads
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   EPOCH - 100 : training on 1732317 raw words (1219842 effective words) took 1.6s, 771199 effective words/s
# 03/07/2021 09:51:14 - INFO - gensim.models.base_any2vec -   training on a 173231700 raw words (122026701 effective words) took 159.8s, 763438 effective words/s

# %%
w2v.wv.save_word2vec_format("w2v_emb.txt",binary=False)
# Out:
# 03/02/2021 15:34:59 - INFO - gensim.models.utils_any2vec -   storing 20564x128 projection weights into w2v_emb.txt
